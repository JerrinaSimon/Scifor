# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('bike_sharing.csv')
df
# Out:
#                  ride_id  rideable_type           started_at  \
# 0       954144C2F67B1932   classic_bike  2022-07-05 08:12:47
# 1       292E027607D218B6   classic_bike  2022-07-26 12:53:38
# 2       57765852588AD6E0   classic_bike  2022-07-03 13:58:49
# 3       B5B6BE44314590E6   classic_bike  2022-07-31 17:44:21
# 4       A4C331F2A00E79E0   classic_bike  2022-07-13 19:49:06
# ...                  ...            ...                  ...
# 823483  605787F70B3B9FD3  electric_bike  2022-07-09 08:32:15
# 823484  F0EECBEE637DF028  electric_bike  2022-07-17 13:27:57
# 823485  B8B091DC72DDAB9D  electric_bike  2022-07-17 14:51:37
# 823486  B4D3FFCC1F3AF5EC  electric_bike  2022-07-28 13:41:50
# 823487  AA9217C8DA3BAC0B  electric_bike  2022-07-29 13:05:20
#
#                    ended_at          start_station_name start_station_id  \
# 0       2022-07-05 08:24:32  Ashland Ave & Blackhawk St            13224
# 1       2022-07-26 12:55:31  Buckingham Fountain (Temp)            15541
# 2       2022-07-03 14:06:32  Buckingham Fountain (Temp)            15541
# 3       2022-07-31 18:42:50  Buckingham Fountain (Temp)            15541
# 4       2022-07-13 20:15:24      Wabash Ave & Grand Ave     TA1307000117
# ...                     ...                         ...              ...
# 823483  2022-07-09 08:56:10                         NaN              NaN
# 823484  2022-07-17 13:33:09                         NaN              NaN
# 823485  2022-07-17 14:57:01                         NaN              NaN
# 823486  2022-07-28 13:47:17                         NaN              NaN
# 823487  2022-07-29 13:10:40                         NaN              NaN
#
#                       end_station_name end_station_id  start_lat  start_lng  \
# 0             Kingsbury St & Kinzie St   KA1503000043  41.907066 -87.667252
# 1                Michigan Ave & 8th St            623  41.869621 -87.623981
# 2                Michigan Ave & 8th St            623  41.869621 -87.623981
# 3               Woodlawn Ave & 55th St   TA1307000164  41.869621 -87.623981
# 4       Sheffield Ave & Wellington Ave   TA1307000052  41.891466 -87.626761
# ...                                ...            ...        ...        ...
# 823483                             NaN            NaN  41.740000 -87.680000
# 823484                             NaN            NaN  41.870000 -87.660000
# 823485                             NaN            NaN  41.950000 -87.640000
# 823486                             NaN            NaN  41.880000 -87.630000
# 823487                             NaN            NaN  41.900000 -87.660000
#
#           end_lat    end_lng member_casual
# 0       41.889177 -87.638506        member
# 1       41.872773 -87.623981        casual
# 2       41.872773 -87.623981        casual
# 3       41.795264 -87.596471        casual
# 4       41.936253 -87.652662        member
# ...           ...        ...           ...
# 823483  41.750000 -87.680000        member
# 823484  41.870000 -87.680000        member
# 823485  41.950000 -87.650000        member
# 823486  41.870000 -87.630000        member
# 823487  41.900000 -87.670000        member
#
# [823488 rows x 13 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 823488 entries, 0 to 823487
# Data columns (total 13 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   ride_id             823488 non-null  object
#  1   rideable_type       823488 non-null  object
#  2   started_at          823488 non-null  object
#  3   ended_at            823488 non-null  object
#  4   start_station_name  711457 non-null  object
#  5   start_station_id    711457 non-null  object
#  6   end_station_name    702537 non-null  object
#  7   end_station_id      702537 non-null  object
#  8   start_lat           823488 non-null  float64
#  9   start_lng           823488 non-null  float64
#  10  end_lat             822541 non-null  float64
#  11  end_lng             822541 non-null  float64
#  12  member_casual       823488 non-null  object
# dtypes: float64(4), object(9)
# memory usage: 81.7+ MB

# %%
df.head()
# Out:
#             ride_id rideable_type           started_at             ended_at  \
# 0  954144C2F67B1932  classic_bike  2022-07-05 08:12:47  2022-07-05 08:24:32
# 1  292E027607D218B6  classic_bike  2022-07-26 12:53:38  2022-07-26 12:55:31
# 2  57765852588AD6E0  classic_bike  2022-07-03 13:58:49  2022-07-03 14:06:32
# 3  B5B6BE44314590E6  classic_bike  2022-07-31 17:44:21  2022-07-31 18:42:50
# 4  A4C331F2A00E79E0  classic_bike  2022-07-13 19:49:06  2022-07-13 20:15:24
#
#            start_station_name start_station_id  \
# 0  Ashland Ave & Blackhawk St            13224
# 1  Buckingham Fountain (Temp)            15541
# 2  Buckingham Fountain (Temp)            15541
# 3  Buckingham Fountain (Temp)            15541
# 4      Wabash Ave & Grand Ave     TA1307000117
#
#                  end_station_name end_station_id  start_lat  start_lng  \
# 0        Kingsbury St & Kinzie St   KA1503000043  41.907066 -87.667252
# 1           Michigan Ave & 8th St            623  41.869621 -87.623981
# 2           Michigan Ave & 8th St            623  41.869621 -87.623981
# 3          Woodlawn Ave & 55th St   TA1307000164  41.869621 -87.623981
# 4  Sheffield Ave & Wellington Ave   TA1307000052  41.891466 -87.626761
#
#      end_lat    end_lng member_casual
# 0  41.889177 -87.638506        member
# 1  41.872773 -87.623981        casual
# 2  41.872773 -87.623981        casual
# 3  41.795264 -87.596471        casual
# 4  41.936253 -87.652662        member

# %%
df.set_index('ride_id')
# Out:
#                   rideable_type           started_at             ended_at  \
# ride_id
# 954144C2F67B1932   classic_bike  2022-07-05 08:12:47  2022-07-05 08:24:32
# 292E027607D218B6   classic_bike  2022-07-26 12:53:38  2022-07-26 12:55:31
# 57765852588AD6E0   classic_bike  2022-07-03 13:58:49  2022-07-03 14:06:32
# B5B6BE44314590E6   classic_bike  2022-07-31 17:44:21  2022-07-31 18:42:50
# A4C331F2A00E79E0   classic_bike  2022-07-13 19:49:06  2022-07-13 20:15:24
# ...                         ...                  ...                  ...
# 605787F70B3B9FD3  electric_bike  2022-07-09 08:32:15  2022-07-09 08:56:10
# F0EECBEE637DF028  electric_bike  2022-07-17 13:27:57  2022-07-17 13:33:09
# B8B091DC72DDAB9D  electric_bike  2022-07-17 14:51:37  2022-07-17 14:57:01
# B4D3FFCC1F3AF5EC  electric_bike  2022-07-28 13:41:50  2022-07-28 13:47:17
# AA9217C8DA3BAC0B  electric_bike  2022-07-29 13:05:20  2022-07-29 13:10:40
#
#                           start_station_name start_station_id  \
# ride_id
# 954144C2F67B1932  Ashland Ave & Blackhawk St            13224
# 292E027607D218B6  Buckingham Fountain (Temp)            15541
# 57765852588AD6E0  Buckingham Fountain (Temp)            15541
# B5B6BE44314590E6  Buckingham Fountain (Temp)            15541
# A4C331F2A00E79E0      Wabash Ave & Grand Ave     TA1307000117
# ...                                      ...              ...
# 605787F70B3B9FD3                         NaN              NaN
# F0EECBEE637DF028                         NaN              NaN
# B8B091DC72DDAB9D                         NaN              NaN
# B4D3FFCC1F3AF5EC                         NaN              NaN
# AA9217C8DA3BAC0B                         NaN              NaN
#
#                                 end_station_name end_station_id  start_lat  \
# ride_id
# 954144C2F67B1932        Kingsbury St & Kinzie St   KA1503000043  41.907066
# 292E027607D218B6           Michigan Ave & 8th St            623  41.869621
# 57765852588AD6E0           Michigan Ave & 8th St            623  41.869621
# B5B6BE44314590E6          Woodlawn Ave & 55th St   TA1307000164  41.869621
# A4C331F2A00E79E0  Sheffield Ave & Wellington Ave   TA1307000052  41.891466
# ...                                          ...            ...        ...
# 605787F70B3B9FD3                             NaN            NaN  41.740000
# F0EECBEE637DF028                             NaN            NaN  41.870000
# B8B091DC72DDAB9D                             NaN            NaN  41.950000
# B4D3FFCC1F3AF5EC                             NaN            NaN  41.880000
# AA9217C8DA3BAC0B                             NaN            NaN  41.900000
#
#                   start_lng    end_lat    end_lng member_casual
# ride_id
# 954144C2F67B1932 -87.667252  41.889177 -87.638506        member
# 292E027607D218B6 -87.623981  41.872773 -87.623981        casual
# 57765852588AD6E0 -87.623981  41.872773 -87.623981        casual
# B5B6BE44314590E6 -87.623981  41.795264 -87.596471        casual
# A4C331F2A00E79E0 -87.626761  41.936253 -87.652662        member
# ...                     ...        ...        ...           ...
# 605787F70B3B9FD3 -87.680000  41.750000 -87.680000        member
# F0EECBEE637DF028 -87.660000  41.870000 -87.680000        member
# B8B091DC72DDAB9D -87.640000  41.950000 -87.650000        member
# B4D3FFCC1F3AF5EC -87.630000  41.870000 -87.630000        member
# AA9217C8DA3BAC0B -87.660000  41.900000 -87.670000        member
#
# [823488 rows x 12 columns]

# %%
df.tail()
# Out:
#                  ride_id  rideable_type           started_at  \
# 823483  605787F70B3B9FD3  electric_bike  2022-07-09 08:32:15
# 823484  F0EECBEE637DF028  electric_bike  2022-07-17 13:27:57
# 823485  B8B091DC72DDAB9D  electric_bike  2022-07-17 14:51:37
# 823486  B4D3FFCC1F3AF5EC  electric_bike  2022-07-28 13:41:50
# 823487  AA9217C8DA3BAC0B  electric_bike  2022-07-29 13:05:20
#
#                    ended_at start_station_name start_station_id  \
# 823483  2022-07-09 08:56:10                NaN              NaN
# 823484  2022-07-17 13:33:09                NaN              NaN
# 823485  2022-07-17 14:57:01                NaN              NaN
# 823486  2022-07-28 13:47:17                NaN              NaN
# 823487  2022-07-29 13:10:40                NaN              NaN
#
#        end_station_name end_station_id  start_lat  start_lng  end_lat  \
# 823483              NaN            NaN      41.74     -87.68    41.75
# 823484              NaN            NaN      41.87     -87.66    41.87
# 823485              NaN            NaN      41.95     -87.64    41.95
# 823486              NaN            NaN      41.88     -87.63    41.87
# 823487              NaN            NaN      41.90     -87.66    41.90
#
#         end_lng member_casual
# 823483   -87.68        member
# 823484   -87.68        member
# 823485   -87.65        member
# 823486   -87.63        member
# 823487   -87.67        member

# %%
df.describe()
# Out:
#            start_lat      start_lng        end_lat        end_lng
# count  823488.000000  823488.000000  822541.000000  822541.000000
# mean       41.904917     -87.647292      41.905166     -87.647417
# std         0.043586       0.028390       0.043779       0.028579
# min        41.640000     -87.840000      41.620000     -87.920000
# 25%        41.882830     -87.660995      41.883073     -87.661206
# 50%        41.902475     -87.643542      41.902973     -87.643948
# 75%        41.931248     -87.629318      41.931248     -87.629318
# max        42.070000     -87.520000      42.370000     -87.520000

# %%
df['rideable_type'].unique()
# Out:
# array(['classic_bike', 'electric_bike', 'docked_bike'], dtype=object)

# %%
count = df['rideable_type'].count()
count
# Out:
# 823488

# %%
missing_values=df.isnull().sum()
missing_values
# Out:
# ride_id                    0
# rideable_type              0
# started_at                 0
# ended_at                   0
# start_station_name    112031
# start_station_id      112031
# end_station_name      120951
# end_station_id        120951
# start_lat                  0
# start_lng                  0
# end_lat                  947
# end_lng                  947
# member_casual              0
# dtype: int64

# %%
df['start_station_name'].isnull().sum()
# Out:
# 112031

# %%
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 823483    False
# 823484    False
# 823485    False
# 823486    False
# 823487    False
# Length: 823488, dtype: bool

# %%
sns.heatmap(df.isnull(),cmap='viridis',cbar=False)
plt.show()
